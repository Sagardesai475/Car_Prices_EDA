# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\SAGAR\\Downloads\\car_prices.csv\\car_prices.csv")
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
#backup of data
df_backup = df.copy()

# %%
#Statistics
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
df.describe(include= 'all')
# Out:
#                  year    make   model    trim    body transmission        vin  \
# count   558837.000000  548536  548438  548186  545642       493485     558833
# unique            NaN      96     973    1963      87            4     550297
# top               NaN    Ford  Altima    Base   Sedan    automatic  automatic
# freq              NaN   93554   19349   55817  199437       475915         22
# mean      2010.038927     NaN     NaN     NaN     NaN          NaN        NaN
# std          3.966864     NaN     NaN     NaN     NaN          NaN        NaN
# min       1982.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 25%       2007.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 50%       2012.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 75%       2013.000000     NaN     NaN     NaN     NaN          NaN        NaN
# max       2015.000000     NaN     NaN     NaN     NaN          NaN        NaN
#
# ...

# %%
#transpose matrix
df.describe(include= 'all').T
# Out:
#                  count  unique                                      top  \
# year          558837.0     NaN                                      NaN
# make            548536      96                                     Ford
# model           548438     973                                   Altima
# trim            548186    1963                                     Base
# body            545642      87                                    Sedan
# transmission    493485       4                                automatic
# vin             558833  550297                                automatic
# state           558837      64                                       fl
# condition     547017.0     NaN                                      NaN
# odometer      558743.0     NaN                                      NaN
# color           558088      46                                    black
# interior        558088      17                                    black
# ...

# %%
#Cleaning Data
df.isnull()
# Out:
#          year   make  model   trim   body  transmission    vin  state  \
# 0       False  False  False  False  False         False  False  False
# 1       False  False  False  False  False         False  False  False
# 2       False  False  False  False  False         False  False  False
# 3       False  False  False  False  False         False  False  False
# 4       False  False  False  False  False         False  False  False
# ...       ...    ...    ...    ...    ...           ...    ...    ...
# 558832  False  False  False  False  False          True  False  False
# 558833  False  False  False  False  False         False  False  False
# 558834  False  False  False  False  False         False  False  False
# 558835  False  False  False  False  False         False  False  False
# 558836  False  False  False  False  False         False  False  False
#
#         condition  odometer  color  interior  seller    mmr  sellingprice  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
percent_isnull = df.isnull().sum()*100/df.shape[0]
percent_isnull
# Out:
# year             0.000000
# make             1.843292
# model            1.860829
# trim             1.905922
# body             2.361154
# transmission    11.694287
# vin              0.000716
# state            0.000000
# condition        2.115107
# odometer         0.016821
# color            0.134028
# interior         0.134028
# seller           0.000000
# mmr              0.006800
# sellingprice     0.002147
# saledate         0.002147
# dtype: float64

# %%
#to put missin/null value as unknown in df
df.fillna(value = 'unknown',inplace = True)
print(df.isnull().sum())
# Out:
# C:\Users\SAGAR\AppData\Local\Temp\ipykernel_22996\914680939.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna(value = 'unknown',inplace = True)
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df["transmission"].unique()
# Out:
# array(['automatic', 'unknown', 'manual', 'Sedan', 'sedan'], dtype=object)

# %%
df["transmission"].value_counts()
# Out:
# transmission
# automatic    475915
# unknown       65352
# manual        17544
# sedan            15
# Sedan            11
# Name: count, dtype: int64

# %%
#Data Visualization

# %%
# Transmission Ratio
palette_color = sns.color_palette('bright') 

explode = [0.1] * len(df["transmission"].value_counts())  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(df["transmission"].value_counts().values, 
        labels=df["transmission"].value_counts().index, 
        explode=explode,
        colors=palette_color, 
        autopct='%.3f%%')
plt.title("Transmission Type Ratios")
plt.show()

print(df["transmission"].value_counts())
# Out:
# transmission
# automatic    475915
# unknown       65352
# manual        17544
# sedan            15
# Sedan            11
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state condition odometer  color interior  \
# 0  5xyktca69fg566472    ca       5.0  16639.0  white    black
# 1  5xyktca69fg561319    ca       5.0   9393.0  white    beige
# 2  wba3c1c51ek116351    ca      45.0   1331.0   gray    black
# 3  yv1612tb4f1310987    ca      41.0  14282.0  white    black
# 4  wba6b2c57ed129731    ca      43.0   2641.0   gray    black
#
#                                    seller      mmr sellingprice  \
# 0                 kia motors america  inc  20500.0      21500.0
# ...

# %%
#Distribution of the brands
plt.figure(figsize=(16,4))
brand_count = df['make'].value_counts()


plt.bar(brand_count.index, brand_count.values, color = 'green')
plt.title('Distribution of brand')
plt.xlabel('Brands')
plt.ylabel('count of brand')
plt.xticks(rotation=90, ha='right')

plt.show()

# %%
#Top10 brand
top_10brand= df['make'].value_counts()[:10].reset_index()
top_10brand
# Out:
#         make  count
# 0       Ford  93554
# 1  Chevrolet  60197
# 2     Nissan  53946
# 3     Toyota  39871
# 4      Dodge  30710
# 5      Honda  27206
# 6    Hyundai  21816
# 7        BMW  20719
# 8        Kia  18077
# 9   Chrysler  17276

# %%
sns.barplot(y = top_10brand['make'], x= top_10brand['count'])


plt.title("Top 10 Brands")
plt.show()

# %%
# Count of sold cars
plt.figure(figsize=(16,4))


sns.countplot(x="year", data=df,palette="magma")
plt.xticks(rotation= 45)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Count of Sold Cars')
plt.show()

# %%
#Creating new column
current_year = 2024
df['age'] = current_year -df['year']
df[['year', 'age']].head()
# Out:
#    year  age
# 0  2015    9
# 1  2015    9
# 2  2014   10
# 3  2015    9
# 4  2014   10

# %%
percentage_age = (df['age'].value_counts()/(len(df)))

# %%
plt.figure(figsize=(16,4))

sns.pointplot(x=percentage_age.index, 
              y=percentage_age.values,
              color='lime')

plt.xticks(rotation= 45)
plt.grid()
plt.show()

# %%
df["condition"] = pd.to_numeric(df["condition"], errors='coerce')

conditions = []


for age in df["age"].unique():
    condition = df[df["age"]==age]["condition"].mean()/df["condition"].max()*100
    
    conditions.append(condition)
    
#     print(f"age: {age}, condition: {condition}")

# %%
percentage_age.values
# Out:
# array([1.83085587e-01, 1.75664818e-01, 1.45069135e-01, 8.68732743e-02,
#        5.63706412e-02, 5.51949853e-02, 4.81589444e-02, 4.73930681e-02,
#        3.82830772e-02, 3.68515327e-02, 3.10323046e-02, 2.37654271e-02,
#        1.73843178e-02, 1.68868561e-02, 1.15740368e-02, 9.35335348e-03,
#        6.01785494e-03, 3.84548625e-03, 2.76645963e-03, 1.52280540e-03,
#        1.27228512e-03, 7.01456775e-04, 3.66833263e-04, 2.36204833e-04,
#        1.19891847e-04, 8.76820969e-05, 3.57886110e-05, 1.96837360e-05,
#        1.96837360e-05, 1.78943055e-05, 1.43154444e-05, 8.94715275e-06,
#        3.57886110e-06, 1.78943055e-06])

# %%
f,ax1 = plt.subplots(figsize =(15,4))


sns.pointplot(x=percentage_age.index, y=conditions, color='red')   


plt.text(35, 2, 'conditions(%)', color='red', fontsize = 15, style = 'italic')

plt.ylabel('Percentage(%) of condition', fontsize = 10,color='blue')


plt.grid()

plt.savefig('graph.png')  # to save the graph

plt.tight_layout()
plt.show()

# %%
df['sellingprice'] = pd.to_numeric(df['sellingprice'], errors='coerce')
Create a scatter plot with a regression line using sns.regplot
sns.regplot(data=df, x="age", y="sellingprice")

# Display the plot
plt.show()

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
categorical_columns = df.select_dtypes(include=["object"]).columns

print("numerical_columns: ", numerical_columns)
print("categorical_columns: ", categorical_columns)
# Out:
# numerical_columns:  Index(['year', 'condition', 'sellingprice', 'age'], dtype='object')
# categorical_columns:  Index(['make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'odometer', 'color', 'interior', 'seller', 'mmr', 'saledate'],
#       dtype='object')

# %%
df[numerical_columns].corr()
# Out:
#                  year  condition  sellingprice      age
# year          1.00000   0.340320      0.586480 -1.00000
# condition     0.34032   1.000000      0.321944 -0.34032
# sellingprice  0.58648   0.321944      1.000000 -0.58648
# age          -1.00000  -0.340320     -0.586480  1.00000

# %%
#Plotting scatter plot

pd.plotting.scatter_matrix(df[numerical_columns], alpha = 0.5, figsize =(12,8), diagonal = 'hist')
plt.suptitle('Scatter Matrix for all the numerical columns', y = 1.02)
plt.show()

# %%
# Convert the 'mmr' column to numeric, coercing errors to NaN
df["mmr"] = pd.to_numeric(df["mmr"], errors='coerce')


# Plot the histogram
plt.figure(figsize=(12, 4))
plt.hist(df["mmr"], bins=50, color='green', alpha=0.7)
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("Frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()

# %%
#Plotting histogram with kernal density estimate 
plt.figure(figsize=(12,4))

sns.histplot(df["mmr"], kde=True, bins=30, binrange=(0,30000))
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12,4))

sns.distplot(df[df["mmr"]<30000]["mmr"], kde=True, bins=30)
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SAGAR\AppData\Local\Temp\ipykernel_22996\3352342009.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["mmr"]<30000]["mmr"], kde=True, bins=30)
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Creating boxplot of all the numerical column 
fig, axes = plt.subplots(nrows=1, ncols=len(numerical_columns), figsize=(20, 4))

for i, column in enumerate(numerical_columns):
    axes[i].boxplot(df[column].dropna())
    axes[i].set_title(f'Box Plot for {column}')
    axes[i].set_ylabel(column)

plt.show()

# %%
#Data cleaning for modfel building

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          558837 non-null  object
#  2   model         558837 non-null  object
#  3   trim          558837 non-null  object
#  4   body          558837 non-null  object
#  5   transmission  558837 non-null  object
#  6   vin           558837 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558837 non-null  object
#  10  color         558837 non-null  object
#  11  interior      558837 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558837 non-null  object
#  16  age           558837 non-null  int64
# ...

# %%
# drop the unique value
df.drop("vin", axis = 1, inplace=True)
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate', 'age'],
#       dtype='object')

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns

numerical_columns
# Out:
# Index(['year', 'condition', 'mmr', 'sellingprice', 'age'], dtype='object')

# %%
df = df[numerical_columns]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   condition     547017 non-null  float64
#  2   mmr           558799 non-null  float64
#  3   sellingprice  558825 non-null  float64
#  4   age           558837 non-null  int64
# dtypes: float64(3), int64(2)
# memory usage: 21.3 MB

# %%
df.head()
# Out:
#    year  condition      mmr  sellingprice  age
# 0  2015        5.0  20500.0       21500.0    9
# 1  2015        5.0  20800.0       21500.0    9
# 2  2014       45.0  31900.0       30000.0   10
# 3  2015       41.0  27500.0       27750.0    9
# 4  2014       43.0  66000.0       67000.0   10

# %%
df.isnull().sum()
# Out:
# year                0
# condition       11820
# mmr                38
# sellingprice       12
# age                 0
# dtype: int64

# %%
df.dropna(subset="sellingprice", inplace=True)
df.isnull().sum()
# Out:
# year                0
# condition       11820
# mmr                26
# sellingprice        0
# age                 0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and test (20%) sets
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

y_train = df_train["sellingprice"]
x_train = df_train.drop("sellingprice", axis = 1)

y_test = df_test["sellingprice"]
x_test = df_test.drop("sellingprice", axis = 1)

print(x_train[:3])
# Out:
#         year  condition      mmr  age
# 389141  2013       41.0  11500.0   11
# 149033  2012       43.0  10850.0   12
# 334714  2006       29.0   7825.0   18

# %%
df_train.isnull().sum()
# Out:
# year               0
# condition       9459
# mmr               20
# sellingprice       0
# age                0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# year               0
# condition       2361
# mmr                6
# sellingprice       0
# age                0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x_train
# Out:
#         year  condition      mmr  age
# 389141  2013       41.0  11500.0   11
# 149033  2012       43.0  10850.0   12
# 334714  2006       29.0   7825.0   18
# 289185  2005       19.0   3650.0   19
# 535150  2013       45.0   8550.0   11
# ...      ...        ...      ...  ...
# 110268  2014        1.0  14400.0   10
# 259178  2008       25.0    600.0   16
# 365839  2011       27.0  43800.0   13
# 131932  2014       42.0  23000.0   10
# 121958  2013        5.0  11200.0   11
#
# [447060 rows x 4 columns]

# %%
from sklearn.impute import SimpleImputer

simple_imputer = SimpleImputer(strategy='mean')

x_train[x_train.columns] = simple_imputer.fit_transform(x_train)
x_test[x_test.columns] = simple_imputer.transform(x_test)

# %%
x_train.head()
# Out:
#           year  condition      mmr   age
# 389141  2013.0       41.0  11500.0  11.0
# 149033  2012.0       43.0  10850.0  12.0
# 334714  2006.0       29.0   7825.0  18.0
# 289185  2005.0       19.0   3650.0  19.0
# 535150  2013.0       45.0   8550.0  11.0

# %%
x_train.isnull().sum()
# Out:
# year         0
# condition    0
# mmr          0
# age          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train[x_train.columns] = scaler.fit_transform(x_train)
x_test[x_test.columns] = scaler.transform(x_test)

# %%
scaler.feature_names_in_
# Out:
# array(['year', 'condition', 'mmr', 'age'], dtype=object)

# %%
scaler.mean_
# Out:
# array([ 1.72901752e-14, -7.39087780e-16, -1.91447289e-16,  1.22730976e-16])

# %%
x_train.head()
# Out:
#             year  condition       mmr       age
# 389141  0.746663   0.779602 -0.233820 -0.746663
# 149033  0.494568   0.930276 -0.300964 -0.494568
# 334714 -1.018005  -0.124444 -0.613441  1.018005
# 289185 -1.270100  -0.877815 -1.044712  1.270100
# 535150  0.746663   1.080951 -0.538550 -0.746663

# %%
# Train the Linear Regression model
model = LinearRegression()
model.fit(x_train["condition"].values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test["condition"].values.reshape(-1,1))
y_pred
# Out:
# array([17892.52726029, 17892.52726029, 13217.72523614, ...,
#        14152.68564097, 15321.38614701,  7140.48260475])

# %%
#Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 85713668.73510201

# %%
# Visualize the true labels vs predicted labels
plt.figure(figsize=(10, 4))

years = scaler.inverse_transform(x_test)[:,1]

sns.lineplot(x=years, y=y_test.values.flatten(), label='True Labels')
sns.lineplot(x=years, y=y_pred.flatten(), label='Predicted Labels')

plt.title('Linear Regression: True Labels vs Predicted Labels')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Train the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)
y_pred
# Out:
# array([31125.22585561, 11947.37432459,  7312.520696  , ...,
#        10644.02499222, 15276.61870057, 16034.97103913])

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 3138956.992924393

# %%
# Visualize the true labels vs predicted labels
plt.figure(figsize=(10, 4))

conditions = scaler.inverse_transform(x_test)[:,1]

sns.lineplot(x=conditions, y=y_test.values.flatten(), label='True Labels')
sns.lineplot(x=conditions, y=y_pred.flatten(), label='Predicted Labels')

plt.title('Linear Regression: True Labels vs Predicted Labels')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SAGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
